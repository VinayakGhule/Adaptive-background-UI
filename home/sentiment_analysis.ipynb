# %%
print("Hello world")
# Out:
# Hello world

# %%
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
text = "TextBlob is a wonderful library for sentiment analysis!"
blob = TextBlob(text)

    # Get the sentiment tuple (polarity, subjectivity)
sentiment = blob.sentiment
print(f"Sentiment: {sentiment}")

    # Access polarity and subjectivity individually
polarity = blob.sentiment.polarity
subjectivity = blob.sentiment.subjectivity
print(f"Polarity: {polarity}")
print(f"Subjectivity: {subjectivity}")

    # Example with a negative sentiment
negative_text = "This movie was terrible and a complete waste of time."
negative_blob = TextBlob(negative_text)
print(f"Negative Sentiment: {negative_blob.sentiment}")
# Out:
# Sentiment: Sentiment(polarity=1.0, subjectivity=1.0)
# Polarity: 1.0
# Subjectivity: 1.0
# Negative Sentiment: Sentiment(polarity=-0.3666666666666667, subjectivity=0.4666666666666666)

# %%
ans= 0-(3)
print(ans)
# Out:
# -3

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

def sentiment_scores(sentence):
    sid_obj = SentimentIntensityAnalyzer()
    sentiment_dict = sid_obj.polarity_scores(sentence)

    print(f"Sentiment Scores: {sentiment_dict}")
    print(f"Negative Sentiment: {sentiment_dict['neg']*100}%")
    print(f"Neutral Sentiment: {sentiment_dict['neu']*100}%")
    print(f"Positive Sentiment: {sentiment_dict['pos']*100}%")

    if sentiment_dict['compound'] >= 0.05:
        print("Overall Sentiment: Positive")
    elif sentiment_dict['compound'] <= -0.05:
        print("Overall Sentiment: Negative")
    else:
        print("Overall Sentiment: Neutral")

if __name__ == "__main__":
    print("\n1st Sentence:")
    sentence = "Vinayak is a good boy but he is not a good student also he is "
    sentiment_scores(sentence)

    print("\n2nd Sentence:")
    sentence = "Shweta played well in the match as usual."
    sentiment_scores(sentence)

    print("\n3rd Sentence:")
    sentence = "I am feeling sad today."
    sentiment_scores(sentence)
# Out:
# 1st Sentence:
# Sentiment Scores: {'neg': 0.172, 'neu': 0.72, 'pos': 0.108, 'compound': -0.2867}
# Negative Sentiment: 17.2%
# Neutral Sentiment: 72.0%
# Positive Sentiment: 10.8%
# Overall Sentiment: Negative
#
# 2nd Sentence:
# Sentiment Scores: {'neg': 0.0, 'neu': 0.571, 'pos': 0.429, 'compound': 0.5423}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 57.099999999999994%
# Positive Sentiment: 42.9%
# Overall Sentiment: Positive
#
# 3rd Sentence:
# Sentiment Scores: {'neg': 0.408, 'neu': 0.395, 'pos': 0.197, 'compound': -0.3818}
# Negative Sentiment: 40.8%
# Neutral Sentiment: 39.5%
# Positive Sentiment: 19.7%
# Overall Sentiment: Negative
